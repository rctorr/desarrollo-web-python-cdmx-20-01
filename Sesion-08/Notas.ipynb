# %%
import matplotlib.pyplot as plt

# Definición de los datos para cada eje
x = (1, 2, 3, 4, 5, 6)
y = (1.73, 1.7, 1.65, 1.71, 1.83, 1.65)

plt.plot(x, y)

# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt

# Definición de los datos para cada eje
x = (1, 2, 3, 4, 5, 6)
y = (1.73, 1.7, 1.65, 1.71, 1.83, 1.65)

plt.plot(x, y)
# Out:
# <div id='8c8d08e5-1260-434c-9b78-eaf0efc49812'></div>

# %% [markdown]
# ---
# ## Ejemplo de uso del módulo pandas

# %%
import numpy as np
import pandas as pd

s = pd.Series( [1, 2.34, np.nan, 5, 7, 9.5, 10/3 ] )
s
# Out:
# 0    1.000000
# 1    2.340000
# 2         NaN
# 3    5.000000
# 4    7.000000
# 5    9.500000
# 6    3.333333
# dtype: float64

# %%
fechas = pd.date_range('20200101', periods=6, freq="M")
fechas
# Out:
# DatetimeIndex(['2020-01-31', '2020-02-29', '2020-03-31', '2020-04-30',
#                '2020-05-31', '2020-06-30'],
#               dtype='datetime64[ns]', freq='M')

# %%
df = pd.DataFrame(
    np.random.randn(6, 4),
    index=fechas, columns=list("ABCD") )
df
# Out:
#                    A         B         C         D
# 2020-01-31 -0.704488 -0.054799 -1.451962 -1.386038
# 2020-02-29  1.653884  1.533657 -0.956878  0.822965
# 2020-03-31  0.435170 -0.035261  0.186555  1.087212
# 2020-04-30 -0.512017 -0.871562  0.958184  0.338596
# 2020-05-31  1.014103 -1.819882 -0.183853  1.125398
# 2020-06-30 -0.515515 -1.095775 -1.726117 -0.440152

# %% [markdown]
# ---
# # Leyendo datos desde archivos csv

# %%
reservaciones = pd.read_csv("reservaciones.csv")
reservaciones
# Out:
#     ID               CONCEPTO  CANTIDAD    PRECIO
# 0    1    alimentos y bebidas         1   5000.00
# 1    1       Habitación doble         1  15000.00
# 2    1  Reservación en evento         1   3999.99
# 3    1         Tour en lancha         2   2175.00
# 4    1             Transporte         3   3000.00
# 5    2    alimentos y bebidas         1   3500.00
# 6    2       Habitación doble         2   4500.00
# 7    2         Tour en ciudad         1   1576.00
# 8    2             Transporte         5    500.00
# 9    3    alimentos y bebidas         3   1850.00
# 10   3    Habitación sencilla         1   1500.00
# 11   3  Reservación en evento         1   2500.00
# 12   3      Caminata nocturna         1    850.00
# 13   3   Tour con luciérnagas         1    750.00
# 14   3             Transporte         6    350.00

# %%
reservaciones.to_json("reservaciones.json")

# %%
reservaciones = pd.read_html

# %% [markdown]
# ---
# ---
# ### Programación orientada a objetos
# ---
# #### EJEMPLO: La definición de un objeto.
#
# Crea un sistema para administrar el carrito de productos de una tienda en línea.

# %% [markdown]
# sistema, carrito, productos, tienda
# carrito, productos
# productos
#
# Producto
# - nombre
# - id
# - precio
# - cantidad
# - subtotal()

# %% [markdown]
# ---
# #### RETO:
#
# Crea un sistema para ....
#
# Y define un  objeto con al menos dos propiedades.

# %% [markdown]
# Smoothie
# - tipo
# - sabor
# - tamaño

# %% [markdown]
# ---
# #### EJEMPLO: La definición de una clase y la creación de objetos de esta clase.
#
# ![image.png](attachment:18c22d7d-6115-4681-aab1-9d63385473f3.png)
#
# Escribe el código en Python para definir la `clase` del objeto definido en el ejemplo anterior, crea un objeto, imprime el objeto e imprime cada una de sus propiedades.

# %%
# escribe tu código aquí

# %% [markdown]
# ---
# #### RETO:
#
# Escribe el código en Python para definir la `clase` del objeto definido en el reto anterior, crea un objeto, imprime el objeto e imprime cada una de sus propiedades.

# %%
# escribe tu código aquí

# %% [markdown]
# ---
# #### RETO:
#
# Vas a crear un sistema para manejar las reservaciones mostradas en el archivo `reservaciones.csv`, define el objeto y sus atributos que permita manejar la información del archivo.

# %%
# escribe tu definición aquí

# %% [markdown]
# ---
# #### EJEMPLO:
#
# Crea el script `reservacio.py` que solicite al usuario un número de reservación e imprima los conceptos de la reservación indicada. Los datos de la reservación se tendrán que leer desde el archivo `reservaciones.csv` y crear los objetos necesario para almacenar los datos.
#
# Nota: Se puede hacer uso de lo ya creado en scrips anteriores.
#
# ```
# $ python reservacion.py 1
# -----------------------------------------------------------
# ID | CONCEPTO              | CANTIDAD | PRECIO
# -----------------------------------------------------------
#  1 | alimentos y bebidas   |        1 |   5000.00
#  1 | Habitación doble      |        1 |  15000.00
#  1 | Reservación en evento |        1 |   3999.99
#  1 | Tour en lancha        |        2 |   2175.00
#  1 | Transporte            |        3 |   3000.00
# -----------------------------------------------------------
# ```

# %% [markdown]
# ---
# ---
# ### Los decoradores en las clases de Python
# ---
# #### EJEMPLO:
#
# En la clase del ejemplo para el carrito de la tienda en línea también se desea conocer el subtotal de cada producto, modificar la definición de la clase para incluirlo.

# %%
# copia y modifica tu código aquí

# %% [markdown]
# ---
# #### RETO:
#
# Modifica el script `reservacion.py` para incluir la columna de subtotal en el resultado.
#
# ```
# $ python reservacion.py 1
# -----------------------------------------------------------
# 1 | CONCEPTO              | CANTIDAD | PRECIO    | SUBTOTAL
# -----------------------------------------------------------
# 1 | alimentos y bebidas   |        1 |   5000.00 |   5000.00
# 1 | Habitación doble      |        1 |  15000.00 |  15000.00
# 1 | Reservación en evento |        1 |   3999.99 |   3999.99
# 1 | Tour en lancha        |        2 |   2175.00 |   4350.00
# 1 | Transporte            |        3 |   3000.00 |   9000.00
# -----------------------------------------------------------
# ```

# %% [markdown]
# ---
# #### RETO:
#
# Modifica el script `reservacion.py` para calcular e incluir el total de la reservación.
#
# ```
# $ python reservacion.py 1
# -----------------------------------------------------------
# 1 | CONCEPTO              | CANTIDAD | PRECIO    | SUBTOTAL
# -----------------------------------------------------------
# 1 | alimentos y bebidas   |        1 |   5000.00 |   5000.00
# 1 | Habitación doble      |        1 |  15000.00 |  15000.00
# 1 | Reservación en evento |        1 |   3999.99 |   3999.99
# 1 | Tour en lancha        |        2 |   2175.00 |   4350.00
# 1 | Transporte            |        3 |   3000.00 |   9000.00
# -----------------------------------------------------------
#   |                       |          |    Total: |  27349.99
# ```

# %% [markdown]
# ---
# ---
# ### Herencia en las clases de Python
# ---
# #### EJEMPLO:
#
# En la clase del ejemplo para el carrito de la tienda se desea contar con la información de cada producto impresa en formato texto haciendo uso del objeto siguiente:
#
# __VistaObjeto__
# - en_txt()

# %%
# copia y modifica tu código aquí

# %% [markdown]
# ---
# #### EJEMPLO:
#
# Modifica el script `reservacion.py` para hacer que la impresión se realice mediante el uso de la clase :
#
# __VistaConcepto__.
# - en_txt()

# %% [markdown]
# ---
# #### RETO:
#
# Modifica el script `reservacion.py` para que el usuario pueda imprimir la reservación en formato JSON haciendo uso de la opción `--json`.
#
# Notas:
# - Sería conveniente crear los métodos `en_json()` en las clases correcpondientes.
# - La versión en JSON no incluye el subtotal
# - La versión en JSON no incluye el total
#
# ```
# $ python reservacion.py 1
# {
#     "ID":1,
#     "CONCEPTOS": [
#         {
#             "CONCEPTO":"alimentos y bebidas",
#             "CANTIDAD":1,
#             "PRECIO":5000.00
#         },
#         {
#             "CONCEPTO":"Habitación doble",
#             "CANTIDAD":1,
#             "PRECIO":15000.00
#         },
#         {
#             "CONCEPTO":"Reservación en evento",
#             "CANTIDAD":1,
#             "PRECIO":3999.99
#         },
#         ...
#     ]
# }
# ```
